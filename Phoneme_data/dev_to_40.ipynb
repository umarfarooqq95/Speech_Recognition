# %% [markdown]
# Contexting on dev set, changing the dimension from 40 columns to 120 columns.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
train=np.load('/gdrive/My Drive/Phoneme_classification/dev.npy',encoding='bytes',allow_pickle=True)
train_labels=np.load('/gdrive/My Drive/Phoneme_classification/dev_labels.npy',encoding='bytes',allow_pickle=True)

# %%
train_con=np.concatenate(train)
train_labels_con=np.concatenate(train_labels)

# %%
train_con.shape
# Out:
# (669294, 40)

# %%
import pandas as pd
cols=['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18', 'F19', 'F20', 'F21', 'F22', 'F23', 'F24', 'F25', 'F26', 'F27', 'F28', 'F29', 'F30', 'F31', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F38', 'F39', 'F40']
x_train_1=pd.DataFrame(train_con,columns=cols)

# %%
x_train_1.head(5)
# Out:
#          F1         F2         F3  ...       F38       F39       F40
# 0 -2.776059 -10.653754  -9.399570  ...  0.236355 -0.580593 -0.817159
# 1 -2.242634  -9.265765  -9.315787  ... -0.261115 -0.462086 -0.944545
# 2 -2.743511  -6.710565 -11.795384  ... -0.631872 -0.565508 -1.358553
# 3 -2.504801 -12.580519 -13.041624  ... -0.599501 -0.679820 -1.094093
# 4 -2.941625  -9.745020  -9.236728  ... -0.249434 -0.420667 -1.558129
#
# [5 rows x 40 columns]

# %%
first_40=x_train_1[0:669292]
last_40=x_train_1[2:669294]
middle_part=x_train_1[1:669293]

# %%
print(first_40.shape)
print(last_40.shape)
print(middle_part.shape)
# Out:
# (669292, 40)
# (669292, 40)
# (669292, 40)

# %%
train_labels_con=train_labels_con.reshape(669294,1)

# %%
train_labels_con=train_labels_con[1:669293]

# %%
train_labels_con.shape
# Out:
# (669292, 1)

# %%
X_train_final=np.concatenate((first_40,middle_part,last_40,train_labels_con),axis=1)

# %%
X_Train=pd.DataFrame(X_train_final,columns=col)

# %%
X_Train.head(5)
# Out:
#          F1         F2         F3  ...      F119      F120  Labels
# 0 -2.776059 -10.653754  -9.399570  ... -0.565508 -1.358553   110.0
# 1 -2.242634  -9.265765  -9.315787  ... -0.679820 -1.094093    45.0
# 2 -2.743511  -6.710565 -11.795384  ... -0.420667 -1.558129    46.0
# 3 -2.504801 -12.580519 -13.041624  ... -0.742236 -1.212537    47.0
# 4 -2.941625  -9.745020  -9.236728  ... -0.644566 -1.358292    24.0
#
# [5 rows x 121 columns]

# %%
delta=X_Train.values

# %%
np.save('/content/drive/My Drive/Phoneme_classification/dev_40.npy',delta)
